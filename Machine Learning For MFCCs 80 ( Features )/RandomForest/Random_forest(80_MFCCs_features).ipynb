# %% [markdown]
# # Load the data:

# %%
import numpy as np
import os
import pandas as pd
mfccs_folder = "D:\Swarming Project buzz 2\Features Extracted Data\MFCCs_Features"

Noneswarming_train = np.load(os.path.join(mfccs_folder, 'Train', 'Noneswarming_train.npy'))
Swarming_train = np.load(os.path.join(mfccs_folder, 'Train', 'Swarming_train.npy'))

Noneswarming_test = np.load(os.path.join(mfccs_folder, 'Test', 'Noneswarming_test.npy'))
Swarming_test = np.load(os.path.join(mfccs_folder, 'Test', 'Swarming_test.npy'))

Noneswarming_val = np.load(os.path.join(mfccs_folder, 'Val', 'Noneswarming_val.npy'))
Swarming_val = np.load(os.path.join(mfccs_folder, 'Val', 'Swarming_val.npy'))

# %% [markdown]
# # Load the data into Pandas DataFrames

# %%
Noneswarming_train_df = pd.DataFrame(np.load(os.path.join(mfccs_folder, 'Train', 'Noneswarming_train.npy')))
Swarming_train_df = pd.DataFrame(np.load(os.path.join(mfccs_folder, 'Train', 'Swarming_train.npy')))

Noneswarming_test_df = pd.DataFrame(np.load(os.path.join(mfccs_folder, 'Test', 'Noneswarming_test.npy')))
Swarming_test_df = pd.DataFrame(np.load(os.path.join(mfccs_folder, 'Test', 'Swarming_test.npy')))

Noneswarming_val_df = pd.DataFrame(np.load(os.path.join(mfccs_folder, 'Val', 'Noneswarming_val.npy')))
Swarming_val_df = pd.DataFrame(np.load(os.path.join(mfccs_folder, 'Val', 'Swarming_val.npy')))

# %% [markdown]
# # Concatenate the data along with labels

# %%
X_train = pd.concat([Noneswarming_train_df, Swarming_train_df], ignore_index=True)
X_test = pd.concat([Noneswarming_test_df, Swarming_test_df], ignore_index=True)
X_val = pd.concat([Noneswarming_val_df, Swarming_val_df], ignore_index=True)

# %%
X_train
# Out:
#                0           1          2          3          4          5   \
# 0     -542.064575  142.921432  31.755577  27.910183   9.562290   7.701846
# 1     -548.349670  142.002304  33.153938  28.572203  10.203482   6.577402
# 2     -535.036499  143.924408  31.395638  28.823423  11.505238   5.078487
# 3     -523.437073  141.479477  39.656937  27.715006   7.365252   6.609511
# 4     -522.435181  137.780151  38.678005  27.361366   7.889681   6.045305
# ...           ...         ...        ...        ...        ...        ...
# 24727 -566.443726   56.460239   1.342612  30.685410  -7.542125  22.769342
# 24728 -566.233154   57.772381   1.188955  30.890989  -6.893257  24.296585
# 24729 -567.630127   57.279484   2.216982  32.089275  -6.116349  24.262182
# 24730 -566.909668   56.530647   1.024287  31.110577  -6.633570  23.655777
# 24731 -565.929565   57.505440   1.230231  31.196342  -6.977430  23.471340
#
#               6          7          8          9   ...        70        71  \
# ...

# %%
print(X_train.shape)
# Out:
# (24732, 80)

# %%
# Create labels
y_train = pd.Series([0] * Noneswarming_train_df.shape[0] + [1] * Swarming_train_df.shape[0], name='label')
y_test = pd.Series([0] * Noneswarming_test_df.shape[0] + [1] * Swarming_test_df.shape[0], name='label')
y_val = pd.Series([0] * Noneswarming_val_df.shape[0] + [1] * Swarming_val_df.shape[0], name='label')

# %%
# Importing necessary libraries.
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler

# Initialize the StandardScaler and scale the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.83842593,  0.3244772 ,  0.604214  , ...,  0.6817872 ,
#          2.4936981 ,  1.2264432 ],
#        [-0.89333105,  0.29924208,  0.69270253, ..., -0.25787297,
#         -0.7540291 , -0.07488944],
#        [-0.7770303 ,  0.35201433,  0.581437  , ..., -0.8128122 ,
#         -1.0323708 ,  0.1800085 ],
#        ...,
#        [-1.0617607 , -2.0268614 , -1.2649932 , ..., -0.00534624,
#         -1.0293952 , -0.90003484],
#        [-1.0554669 , -2.0474212 , -1.3404672 , ..., -0.81159145,
#         -1.0313556 , -0.63538134],
#        [-1.0469049 , -2.0206578 , -1.327435  , ..., -0.8911662 ,
#         -0.63039076, -0.4477883 ]], dtype=float32)

# %%
# Initialize the Random Forest model
random_forest_model = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
import time
t1 = time.time()
# Train the model
random_forest_model.fit(X_train_scaled, y_train)

# Make predictions on the validation set
y_test_pred = random_forest_model.predict(X_test_scaled)

# Evaluate the model
accuracy = accuracy_score(y_test, y_test_pred)
print(f"Testing Accuracy: {accuracy:.2f}")

# Additional evaluation metrics
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred))
t2 = time.time()
# Out:
# Testing Accuracy: 0.99
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      5000
#            1       0.99      1.00      0.99      6575
#
#     accuracy                           0.99     11575
#    macro avg       0.99      0.99      0.99     11575
# weighted avg       0.99      0.99      0.99     11575

# %%
print(f"time elapsed: {t2-t1} seconds or {int((t2-t1)//60)} minutes and {int((t2-t1)-(t2-t1)//60*60)} seconds")
# Out:
# time elapsed: 22.970112323760986 seconds or 0 minutes and 22 seconds

# %% [markdown]
# # ROC Curve

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Make predictions on the test set
y_test_prob = random_forest_model.predict_proba(X_test_scaled)[:, 1]

# Compute ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_test_prob)
roc_auc = roc_auc_score(y_test, y_test_prob)

# Plot the ROC curve
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")

# Save the plot as an image file (e.g., PNG)
plt.savefig('ROC of Randomfoest (80 MFCCs features).png')

# Display the plot
plt.show()

# %% [markdown]
# # Confunsion Matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Make predictions on the test set
y_test_pred = random_forest_model.predict(X_test_scaled)

# Compute confusion matrix
conf_matrix = confusion_matrix(y_test, y_test_pred)

# Plot confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Non-Swarming', 'Swarming'],
            yticklabels=['Non-Swarming', 'Swarming'])
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.savefig('Confusion Matrix of Randomfoest (80 MFCCs features).png')
plt.show()
